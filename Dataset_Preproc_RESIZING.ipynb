# %% [markdown]
# <a href="https://colab.research.google.com/github/Smart-Pigs/Depth-Images/blob/main/Dataset_Preproc_RESIZING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Make sure you have these folders as shortcuts in your drive - 
#/content/gdrive/MyDrive/Morota-video-data/ 
#/content/gdrive/MyDrive/DEPTH_INDIVIDUAL/

# %%
#Mount Google Drive 
from google.colab import drive
drive.mount('/content/gdrive',force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# !cp /content/gdrive/MyDrive/DEPTH_INDIVIDUAL/SQUARE/SQUARE_WEEK1-2.zip .

# %%
# !cp /content/gdrive/MyDrive/DEPTH_INDIVIDUAL/SQUARE/SQUARE_WEEK3-4.zip .

# %%
# !cp /content/gdrive/MyDrive/DEPTH_INDIVIDUAL/SQUARE/SQUARE_WEEK5-6.zip .

# %%
# !cp /content/gdrive/MyDrive/DEPTH_INDIVIDUAL/SQUARE/SQUARE_WEEK7-8.zip .

# %%
# !cp /content/gdrive/MyDrive/DEPTH_INDIVIDUAL/SQUARE/SQUARE_WEEK9-10.zip .

# %%
# !unzip -qq SQUARE_WEEK1-2.zip -d .

# %%
# !unzip -qq SQUARE_WEEK3-4.zip -d .

# %%
# !unzip -qq SQUARE_WEEK5-6.zip -d .

# %%
# !unzip -qq SQUARE_WEEK7-8.zip -d .

# %%
# !unzip -qq SQUARE_WEEK9-10.zip -d .

# %%
import cv2
from tqdm import tqdm
from google.colab.patches import cv2_imshow
import os
from glob import glob

dim = (512,512)

for PATH in ['Week1','Week2','Week3','Week4','Week5','Week6','Week7','Week8','Week9','Week10']:
    print(PATH)
    result = [y for x in os.walk(PATH) for y in glob(os.path.join(x[0], '*.jpg'))]
    for img in tqdm(result):
      image = cv2.imread(img)
      os.remove(img)
      image = cv2.resize(image, dim, interpolation = cv2.INTER_AREA)
      cv2.imwrite(img,image)
# Out:
# Week1
# 100%|██████████| 1013/1013 [00:00<00:00, 5212.46it/s]
# Week2
# 100%|██████████| 5773/5773 [00:01<00:00, 5346.05it/s]
# Week3
# 100%|██████████| 11785/11785 [00:03<00:00, 3813.21it/s]
# Week4
# 100%|██████████| 9993/9993 [00:02<00:00, 3678.16it/s]
# Week5
# 100%|██████████| 9388/9388 [00:01<00:00, 5086.90it/s]
# Week6
# 100%|██████████| 13941/13941 [00:02<00:00, 5135.15it/s]
# Week7
# 100%|██████████| 13590/13590 [00:02<00:00, 4822.26it/s]
# Week8
# 100%|██████████| 14099/14099 [00:03<00:00, 4166.29it/s]
# Week9
# 100%|██████████| 12183/12183 [00:03<00:00, 3548.92it/s]
# Week10
# 100%|██████████| 13745/13745 [00:02<00:00, 4824.66it/s]

# %%
# !zip -r SQUARE_WEEK1-10_512.zip Week1 Week2 Week3 Week4 Week5 Week6 Week7 Week8 Week9 Week10
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: Week10/20211119/20211119_3330/_Depth_1124.jpg (deflated 23%)
#   adding: Week10/20211119/20211119_3330/_Depth_1017.jpg (deflated 23%)
#   adding: Week10/20211119/20211119_3330/_Depth_535.jpg (deflated 22%)
#   adding: Week10/20211119/20211119_3330/_Depth_524.jpg (deflated 23%)
#   adding: Week10/20211119/20211119_3330/_Depth_1056.jpg (deflated 22%)
#   adding: Week10/20211119/20211119_3330/_Depth_960.jpg (deflated 23%)
#   adding: Week10/20211119/20211119_3330/_Depth_224.jpg (deflated 23%)
#   adding: Week10/20211119/20211119_3330/_Depth_1023.jpg (deflated 23%)
#   adding: Week10/20211119/20211119_3330/_Depth_327.jpg (deflated 23%)
#   adding: Week10/20211119/20211119_3330/_Depth_389.jpg (deflated 23%)
#   adding: Week10/20211119/20211119_3330/_Depth_511.jpg (deflated 23%)
#   adding: Week10/20211119/20211119_3330/_Depth_105.jpg (deflated 23%)
#   adding: Week10/20211119/20211119_3330/_Depth_833.jpg (deflated 23%)
# ...

# %%
# !mv SQUARE_WEEK1-10*.zip /content/gdrive/MyDrive/DEPTH_INDIVIDUAL/SQUARE/

# %% [markdown]
# <a href="https://colab.research.google.com/github/Smart-Pigs/Depth-Images/blob/main/WE_MobileNet_TL_Cropped.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Make sure you have this folder as shortcut in your drive - /content/gdrive/MyDrive/Morota-video-data/

# %%
#Mount Google Drive 
from google.colab import drive
drive.mount('/content/gdrive',force_remount=True)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ### Data Loading

# %%
#@markdown Select resolution of input dataset and weeks of data

Instantiate_New_Dataset = True #@param {type:"boolean"}
Refresh_Old_Dataset = False #@param {type:"boolean"}

if Instantiate_New_Dataset == True:
  # !rm -rf Week*/

Resolution = "256"  #@param ['720', '512', '256']

if Refresh_Old_Dataset == False:
  if Resolution == "720":
    # !cp /content/gdrive/MyDrive/Morota-video-data/DEPTH_INDIVIDUAL/CROPPED/CROPPED_WEEK1-10_720.zip .
    # !unzip -qq CROPPED_WEEK1-10_720.zip -d .
    # !rm -rf *WEEK*.zip

  if Resolution == "512":
    # !cp /content/gdrive/MyDrive/Morota-video-data/DEPTH_INDIVIDUAL/CROPPED/CROPPED_WEEK1-10_512.zip .
    # !unzip -qq CROPPED_WEEK1-10_512.zip -d .
    # !rm -rf *WEEK*.zip

  if Resolution == "256":
    # !cp /content/gdrive/MyDrive/Morota-video-data/DEPTH_INDIVIDUAL/CROPPED/CROPPED_WEEK1-10_256.zip .
    # !unzip -qq CROPPED_WEEK1-10_256.zip -d .
    # !rm -rf *WEEK*.zip

# %% [markdown]
# ### Mapping Table Input

# %%
import pandas as pd

# %%
final_map = pd.read_csv("/content/gdrive/MyDrive/Morota-video-data/final_mapping.csv")

# %%
weeks = final_map

# %%
weeks
# Out:
#                                            image_path      Date   Pig  weight  \
# 0      Week1/20210922/20210922_3330_b/_Depth_4683.jpg  20210922  3330    15.5
# 1      Week1/20210922/20210922_3330_b/_Depth_4778.jpg  20210922  3330    15.5
# 2      Week1/20210922/20210922_3330_b/_Depth_4579.jpg  20210922  3330    15.5
# 3      Week1/20210922/20210922_3330_b/_Depth_4578.jpg  20210922  3330    15.5
# 4      Week1/20210922/20210922_3330_b/_Depth_4584.jpg  20210922  3330    15.5
# ...                                               ...       ...   ...     ...
# 96220   Week10/20211119/20211119_3342/_Depth_3504.jpg  20211119  3342    56.6
# 96221   Week10/20211119/20211119_3342/_Depth_3318.jpg  20211119  3342    56.6
# 96222   Week10/20211119/20211119_3342/_Depth_3476.jpg  20211119  3342    56.6
# 96223   Week10/20211119/20211119_3342/_Depth_3169.jpg  20211119  3342    56.6
# 96224   Week10/20211119/20211119_3342/_Depth_3022.jpg  20211119  3342    56.6
#
#        Week
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ...     ...
# 96220    10
# 96221    10
# 96222    10
# 96223    10
# 96224    10
#
# [96225 rows x 5 columns]

# %%
weeks_train = weeks[weeks["Pig"] != 3330]
#weeks_test = weeks[weeks['image_path'].str.contains('Week1/|Week2/')]

# %%
weeks_test = weeks[weeks["Pig"] == 3330]
#weeks_train = weeks[~weeks['image_path'].str.contains('Week1/|Week2/')]

# %%
image_paths_train = weeks_train['image_path'].values
labels_train = weeks_train['weight'].values
image_paths_test = weeks_test['image_path'].values
labels_test = weeks_test['weight'].values

# %%
import tensorflow as tf
import pandas as pd
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
input_train_dataset = tf.data.Dataset.from_tensor_slices((image_paths_train, labels_train))
input_test_dataset = tf.data.Dataset.from_tensor_slices((image_paths_test, labels_test))

# %%
print("Number of elements in the train dataset:", tf.data.experimental.cardinality(input_train_dataset).numpy())
print("Number of elements in the test dataset:", tf.data.experimental.cardinality(input_test_dataset).numpy())
# Out:
# Number of elements in the train dataset: 69568
# Number of elements in the test dataset: 26657

# %% [markdown]
# ### Unaugmented

# %%
IMG_SIZE = int(Resolution)
channels = 1

# %%
def preprocess_image(image_path, label):
    img = tf.io.read_file(image_path)
    img = tf.image.decode_jpeg(img, channels=3)
#----------change gray scale and rgb----------------------------
    img = tf.image.rgb_to_grayscale(img)
#-------------------------------------------------------------------
    if int(Resolution) > IMG_SIZE:
      img = tf.image.resize(img, [IMG_SIZE, IMG_SIZE])
    img = tf.cast(img, tf.float32) / 255.0
    return img, label

# %%
batch_size = 128

train_dataset = input_train_dataset.shuffle(len(labels_train))
train_dataset = train_dataset.map(preprocess_image)
train_dataset = train_dataset.batch(batch_size)
train_dataset = train_dataset.prefetch(tf.data.AUTOTUNE)

test_dataset = input_test_dataset.map(preprocess_image)
test_dataset = test_dataset.batch(batch_size)
test_dataset = test_dataset.prefetch(tf.data.AUTOTUNE)

# %%
def visualize_sample(dataset):
    for img_batch, label_batch in dataset.take(1):
        img = img_batch[0].numpy().squeeze()

        plt.figure(figsize=(10, 5))
        plt.imshow(img, cmap='gray')
        plt.title('Depth Image')
        plt.axis('off')

        plt.show()

visualize_sample(train_dataset)

# %% [markdown]
# ### Training after loading Pretrained Weights

# %%
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Concatenate
from tensorflow.keras.models import Model

def create_transfer_learning_cnn():
    base_model = MobileNetV2(input_shape=(IMG_SIZE, IMG_SIZE, 3), include_top=False, weights='imagenet')
    base_model.trainable = False  # Freeze the pre-trained layers

    # If you are using a grayscale image, you need to duplicate the single channel to match the required input shape
    depth_input = Input(shape=(IMG_SIZE, IMG_SIZE, 1), name="depth_input")
    x = Concatenate()([depth_input, depth_input, depth_input])
    
    x = base_model(x, training=False)
    x = GlobalAveragePooling2D()(x)
    x = Dense(32, activation="relu")(x)
    output = Dense(1)(x)

    model = Model(inputs=depth_input, outputs=output)
    return model

model = create_transfer_learning_cnn()
model.compile(optimizer='adam', loss='mse', metrics=['mae', 'mape'])
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 1s 0us/step

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  depth_input (InputLayer)       [(None, 256, 256, 1  0           []
#                                 )]
#
#  concatenate (Concatenate)      (None, 256, 256, 3)  0           ['depth_input[0][0]',
#                                                                   'depth_input[0][0]',
#                                                                   'depth_input[0][0]']
#
#  mobilenetv2_1.00_224 (Function  (None, 8, 8, 1280)  2257984     ['concatenate[0][0]']
#  al)
#
#  global_average_pooling2d (Glob  (None, 1280)        0           ['mobilenetv2_1.00_224[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 32)           40992       ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense_1 (Dense)                (None, 1)            33          ['dense[0][0]']
#
# ==================================================================================================
# Total params: 2,299,009
# Trainable params: 41,025
# Non-trainable params: 2,257,984
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# Create the callbacks
checkpoint_filepath = 'best_model.h5'
checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='val_mape',
    save_best_only=True,
    verbose=1,
    mode='min'
)

early_stopping_callback = EarlyStopping(
    monitor='val_mape',
    patience=5,
    verbose=1,
    mode='min',
    restore_best_weights=True
)

callbacks = [checkpoint_callback, early_stopping_callback]

# %%
history = model.fit(
    train_dataset,
    epochs=50,
    validation_data=test_dataset,
    callbacks=callbacks
)
# Out:
# Epoch 1/50
# 544/544 [==============================] - ETA: 0s - loss: 58.7808 - mae: 5.5398 - mape: 18.8671
# Epoch 1: val_mape improved from inf to 15.69834, saving model to best_model.h5
# 544/544 [==============================] - 212s 366ms/step - loss: 58.7808 - mae: 5.5398 - mape: 18.8671 - val_loss: 56.3384 - val_mae: 5.5870 - val_mape: 15.6983
# Epoch 2/50
# 544/544 [==============================] - ETA: 0s - loss: 11.0491 - mae: 2.4115 - mape: 8.3420
# Epoch 18: val_mape did not improve from 11.94379
# 544/544 [==============================] - 148s 271ms/step - loss: 11.0491 - mae: 2.4115 - mape: 8.3420 - val_loss: 40.2810 - val_mae: 4.5381 - val_mape: 12.5335
# Epoch 19/50
# 544/544 [==============================] - ETA: 0s - loss: 10.9142 - mae: 2.3972 - mape: 8.2963
# Epoch 19: val_mape did not improve from 11.94379
# 544/544 [==============================] - 144s 265ms/step - loss: 10.9142 - mae: 2.3972 - mape: 8.2963 - val_loss: 36.4755 - val_mae: 4.3544 - val_mape: 12.1270
# Epoch 20/50
# 544/544 [==============================] - ETA: 0s - loss: 10.6909 - mae: 2.3701 - mape: 8.1984
# Epoch 20: val_mape did not improve from 11.94379
# 544/544 [==============================] - 142s 261ms/step - loss: 10.6909 - mae: 2.3701 - mape: 8.1984 - val_loss: 39.9557 - val_mae: 4.5587 - val_mape: 12.5843
# Epoch 21/50
# 544/544 [==============================] - ETA: 0s - loss: 10.6416 - mae: 2.3629 - mape: 8.1667
# Epoch 21: val_mape did not improve from 11.94379
# 544/544 [==============================] - 144s 264ms/step - loss: 10.6416 - mae: 2.3629 - mape: 8.1667 - val_loss: 39.3407 - val_mae: 4.5072 - val_mape: 12.5590
# Epoch 22/50
# 544/544 [==============================] - ETA: 0s - loss: 10.4085 - mae: 2.3398 - mape: 8.0895
# Epoch 22: val_mape did not improve from 11.94379
# Restoring model weights from the end of the best epoch: 17.
# 544/544 [==============================] - 147s 269ms/step - loss: 10.4085 - mae: 2.3398 - mape: 8.0895 - val_loss: 37.3884 - val_mae: 4.3673 - val_mape: 12.1280
# Epoch 22: early stopping

# %%
test_loss, test_mae, test_mape = model.evaluate(test_dataset)
print('Test loss:', test_loss)
print('Test mean absolute error:', test_mae)
print('Test mean absolute percentage error:', test_mape)
# Out:
# 209/209 [==============================] - 41s 197ms/step - loss: 34.1449 - mae: 4.2245 - mape: 11.9438
# Test loss: 34.14485549926758
# Test mean absolute error: 4.224471569061279
# Test mean absolute percentage error: 11.943791389465332

# %% [markdown]
# ### Finetuning

# %%
# Unfreeze some or all layers of the base model
num_layers_to_freeze = 100
for layer in model.layers[2].layers[:num_layers_to_freeze]:
    layer.trainable = False
for layer in model.layers[2].layers[num_layers_to_freeze:]:
    layer.trainable = True

# Compile the model with a lower learning rate for fine-tuning
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-5)
model.compile(optimizer=optimizer, loss='mse', metrics=['mae', 'mape'])

# %%
# Add ModelCheckpoint and EarlyStopping callbacks
checkpoint_filepath = 'best_model_ft.h5'
checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='val_loss',
    save_best_only=True,
    verbose=1,
    mode='min'
)

early_stopping_callback = EarlyStopping(
    monitor='val_loss',
    patience=10,
    verbose=1,
    mode='min',
    restore_best_weights=True
)

callbacks = [checkpoint_callback, early_stopping_callback]

# %%
# Fine-tune the model with the unfrozen base layers
history_fine_tuning = model.fit(
    train_dataset,
    epochs=50,
    validation_data=test_dataset,
    callbacks=callbacks
)
# Out:
# Epoch 1/50
# 544/544 [==============================] - ETA: 0s - loss: 10.5404 - mae: 2.3508 - mape: 8.1397
# Epoch 1: val_loss improved from inf to 36.66231, saving model to best_model_ft.h5
# 544/544 [==============================] - 151s 270ms/step - loss: 10.5404 - mae: 2.3508 - mape: 8.1397 - val_loss: 36.6623 - val_mae: 4.3437 - val_mape: 12.1211
# Epoch 2/50
# 544/544 [==============================] - ETA: 0s - loss: 10.4976 - mae: 2.3456 - mape: 8.1171
# Epoch 2: val_loss did not improve from 36.66231
# 544/544 [==============================] - 146s 267ms/step - loss: 10.4976 - mae: 2.3456 - mape: 8.1171 - val_loss: 37.0355 - val_mae: 4.3643 - val_mape: 12.1584
# Epoch 3/50
# 544/544 [==============================] - ETA: 0s - loss: 10.4814 - mae: 2.3436 - mape: 8.1093
# Epoch 3: val_loss did not improve from 36.66231
# 544/544 [==============================] - 146s 269ms/step - loss: 10.4814 - mae: 2.3436 - mape: 8.1093 - val_loss: 37.1701 - val_mae: 4.3735 - val_mape: 12.1779
# Epoch 4/50
# 544/544 [==============================] - ETA: 0s - loss: 10.4748 - mae: 2.3425 - mape: 8.1040
# Epoch 4: val_loss improved from 36.66231 to 36.55079, saving model to best_model_ft.h5
# 544/544 [==============================] - 146s 268ms/step - loss: 10.4748 - mae: 2.3425 - mape: 8.1040 - val_loss: 36.5508 - val_mae: 4.3417 - val_mape: 12.1151
# Epoch 5/50
# 544/544 [==============================] - ETA: 0s - loss: 10.4661 - mae: 2.3422 - mape: 8.1032
# Epoch 5: val_loss did not improve from 36.55079
# 544/544 [==============================] - 146s 268ms/step - loss: 10.4661 - mae: 2.3422 - mape: 8.1032 - val_loss: 36.7428 - val_mae: 4.3483 - val_mape: 12.1311
# Epoch 6/50
# 544/544 [==============================] - ETA: 0s - loss: 10.4603 - mae: 2.3413 - mape: 8.1005
# Epoch 6: val_loss did not improve from 36.55079
# 544/544 [==============================] - 145s 267ms/step - loss: 10.4603 - mae: 2.3413 - mape: 8.1005 - val_loss: 36.7876 - val_mae: 4.3511 - val_mape: 12.1392
# Epoch 7/50
# 544/544 [==============================] - ETA: 0s - loss: 10.4550 - mae: 2.3404 - mape: 8.0975
# Epoch 7: val_loss did not improve from 36.55079
# 544/544 [==============================] - 144s 264ms/step - loss: 10.4550 - mae: 2.3404 - mape: 8.0975 - val_loss: 37.0297 - val_mae: 4.3665 - val_mape: 12.1634
# Epoch 8/50
# 544/544 [==============================] - ETA: 0s - loss: 10.4510 - mae: 2.3399 - mape: 8.0947
# Epoch 8: val_loss improved from 36.55079 to 36.42184, saving model to best_model_ft.h5
# 544/544 [==============================] - 146s 268ms/step - loss: 10.4510 - mae: 2.3399 - mape: 8.0947 - val_loss: 36.4218 - val_mae: 4.3318 - val_mape: 12.1033
# Epoch 9/50
# 544/544 [==============================] - ETA: 0s - loss: 10.4450 - mae: 2.3392 - mape: 8.0917
# Epoch 9: val_loss improved from 36.42184 to 36.21439, saving model to best_model_ft.h5
# 544/544 [==============================] - 148s 272ms/step - loss: 10.4450 - mae: 2.3392 - mape: 8.0917 - val_loss: 36.2144 - val_mae: 4.3199 - val_mape: 12.0855
# Epoch 10/50
# 453/544 [=======================>......] - ETA: 17s - loss: 10.4927 - mae: 2.3411 - mape: 8.0915

# %%
# Evaluate the fine-tuned model
test_loss, test_mae, test_mape = model.evaluate(test_dataset)
print('Test loss:', test_loss)
print('Test mean absolute error:', test_mae)
print('Test mean absolute percentage error:', test_mape)
